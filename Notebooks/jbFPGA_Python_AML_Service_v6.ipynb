# %%
# https://github.com/azure/aml-real-time-ai
# https://jbfpgaaml-jbarnes1.notebooks.azure.com/j/notebooks/project-brainwave-quickstart.ipynb
# Deploy models with the Azure Machine Learning service
# https://docs.microsoft.com/en-us/azure/machine-learning/service/how-to-deploy-and-where#choose-a-compute-target
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# ---------------------------------------------------------------------------------------
# Set Azure Subscription Parms
# ---------------------------------------------------------------------------------------
#!az login
# !Connect-AzAccount
# !Select-AzSubscription -Subscription "82d7b191-5a8c-4cbf-a9f9-9aa5fb50feaa"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# -----------------------------------------------------------------------
# SET-UP workSpace Parms
# -----------------------------------------------------------------------
import os
import tensorflow as tf
subscription_id = os.getenv("SUBSCRIPTION_ID", default="82d7b191-5a8c-4cbf-a9f9-9aa5fb50feaa")
resource_group = os.getenv("RESOURCE_GROUP", default="jbfpga")
workspace_name = os.getenv("WORKSPACE_NAME", default="jbfpgamlws")
workspace_region = os.getenv("WORKSPACE_REGION", default="eastus2")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# -----------------------------------------------------------------------
# WRITE (Optional) WorkSpace Parms
# -----------------------------------------------------------------------
from azureml.core import Workspace

try:
    ws = Workspace(subscription_id = subscription_id, resource_group = resource_group, workspace_name = workspace_name)
    # write the details of the workspace to a configuration file to the notebook library
    ws.write_config()
    print("Workspace configuration succeeded.")
except:
    print("Workspace not accessible.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (six 1.10.0 (/usr/lib/python3/dist-packages), Requirement.parse(&apos;six&gt;=1.11.0&apos;)).
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code ATJLVUQZC to authenticate.
# Interactive authentication successfully completed.
# Workspace configuration succeeded.
# </div>

# %%
# -----------------------------------
# Retrieve Workspace
# -----------------------------------
from azureml.core import Workspace

ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">jbfpgamlws
# jbfpga
# eastus2
# 82d7b191-5a8c-4cbf-a9f9-9aa5fb50feaa
# </div>

# %%
# ------------------------------
# Input images as a two-dimensional tensor containing an arbitrary number of images represented a strings
# ------------------------------
import azureml.accel.models.utils as utils
tf.reset_default_graph()

in_images = tf.placeholder(tf.string)
image_tensors = utils.preprocess_array(in_images)
print(image_tensors.shape)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(?, 224, 224, 3)
# </div>

# %%
# ------------------------------
# Featurizer
# ------------------------------
#We use ResNet50 as a featurizer. In this step we initialize the model. This downloads a TensorFlow checkpoint of the quantized ResNet50.
from azureml.accel.models import QuantizedResnet50
save_path = os.path.expanduser('~/models')
model_graph = QuantizedResnet50(save_path, is_frozen = True)
feature_tensor = model_graph.import_graph_def(image_tensors)
print(model_graph.version)
print(feature_tensor.name)
print(feature_tensor.shape)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1.1.2
# brainwave_target_node_1_Version_0.1:0
# (?, 1, 1, 2048)
# </div>

# %%
# ------------------------------
# Classifier
# ------------------------------
#The model we downloaded includes a classifier which takes the output of the ResNet50 and identifies an image. This classifier is trained on the ImageNet dataset. We are going to use this classifier for our service. The next #notebook shows how to train a classifier for a different data set. The input to the classifier is a tensor matching the output of our ResNet50 featurizer.
classifier_output = model_graph.get_default_classifier(feature_tensor)
print(classifier_output)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tensor(&quot;classifier/resnet_v1_50/predictions/Softmax:0&quot;, shape=(?, 1000), dtype=float32)
# </div>

# %%
# ---------------------------------------
# SAVE Model
# model_name must be lowercase
# ---------------------------------------

#save_path = os.path.expanduser('~/models/save/')
save_path = "/databricks/driver/"

model_name = "resnet50-4"
model_save_path = os.path.join(save_path, model_name)
print("Saving model in {}".format(model_save_path))

with tf.Session() as sess:
    model_graph.restore_weights(sess)
    tf.saved_model.simple_save(sess, model_save_path,
                                   inputs={'images': in_images},
                                   outputs={'output_alias': classifier_output})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Saving model in /databricks/driver/resnet50-4
# INFO:tensorflow:Restoring parameters from /root/models/msfprn50/1.1.2/resnet50_bw
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /databricks/driver/resnet50-4/saved_model.pb
# </div>

# %%
# -----------------------------------
# Important! Save names of input and output tensors
# -----------------------------------
input_tensors = in_images.name
output_tensors = classifier_output.name

print(input_tensors)
print(output_tensors)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Placeholder:0
# classifier/resnet_v1_50/predictions/Softmax:0
# </div>

# %%
# ----------------------------------
# REGISTER MODEL
# ----------------------------------
save_path =  os.path.expanduser("")
model_name = "resnet50-4"
model_save_path = os.path.join(save_path, model_name)


from azureml.core.model import Model

registered_model = Model.register(workspace = ws,
                                  model_path = model_save_path,
                                  model_name = model_name)

print("Successfully registered: ", registered_model.name, registered_model.description, registered_model.version, sep = '\t')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Registering model resnet50-4
# Successfully registered: 	resnet50-4	None	1
# </div>

# %%
# ----------------------------------
# CONVERT MODEL
# Note: Conversion may take a while and on average for FPGA model it is about 1-3 minutes and it depends on model type
# ----------------------------------
from azureml.accel import AccelOnnxConverter

convert_request = AccelOnnxConverter.convert_tf_model(ws, registered_model, input_tensors, output_tensors)
# If it fails, you can run wait_for_completion again with show_output=True. False
convert_request.wait_for_completion(show_output = True)
# If the above call succeeded, get the converted model
converted_model = convert_request.result
print("\nSuccessfully converted: ", converted_model.name, converted_model.url, converted_model.version, 
      converted_model.id, converted_model.created_time, '\n')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Running.........................
# Succeeded
# Operation 1604cafa-3f45-44fd-8760-52cc8dfcde22 completed, operation state &quot;Succeeded&quot;
# sas url to download model conversion logs https://jbfpgamlws2385341934.blob.core.windows.net/azureml/LocalUpload/a2189f4fd74648cc93cbb949b81ff140/conversion_log?sv=2018-03-28&amp;sr=b&amp;sig=B5Uk6S7Msdpz4%2FtjEg0iRIEfulckrLgXIjr3AIxr3Lo%3D&amp;st=2019-07-26T15%3A49%3A16Z&amp;se=2019-07-26T23%3A59%3A16Z&amp;sp=r
# [2019-07-26 15:57:10Z]: Starting model conversion process
# [2019-07-26 15:57:10Z]: Downloading model for conversion
# [2019-07-26 15:57:14Z]: Converting model
# [2019-07-26 15:57:15Z]: converter std: 2019-07-26 15:57:15,952 [INFO ]  Parsing conversion options
# [2019-07-26 15:57:15Z]: converter std: 2019-07-26 15:57:15,952 [DEBUG]  Options: {&apos;toolVersion&apos;: &apos;1.0&apos;, &apos;toolName&apos;: &apos;fpga&apos;, &apos;input_node_names&apos;: &apos;Placeholder:0&apos;, &apos;require_fpga_conversion&apos;: &apos;True&apos;, &apos;output_node_names&apos;: &apos;classifier/resnet_v1_50/predictions/Softmax:0&apos;, &apos;sourceModelFlavor&apos;: &apos;tf&apos;, &apos;targetModelFlavor&apos;: &apos;accelonnx&apos;, &apos;unpack&apos;: &apos;true&apos;}
# [2019-07-26 15:57:15Z]: converter std: 2019-07-26 15:57:15,953 [INFO ]  Begin splitting graph ...
# [2019-07-26 15:57:15Z]: converter std: 2019-07-26 15:57:15,953 [INFO ]  input path =&gt; /tmp/xh3x4a4g.d4z/input
# [2019-07-26 15:57:15Z]: converter std: 2019-07-26 15:57:15,953 [INFO ]  output path =&gt; /tmp/tmppfziwl0d
# [2019-07-26 15:57:15Z]: converter std: 2019-07-26 15:57:15,953 [INFO ]  Splitting requires FPGA only
# [2019-07-26 15:57:15Z]: converter std: 2019-07-26 15:57:15,954 [DEBUG]  Descending into /tmp/xh3x4a4g.d4z/input/resnet50-4
# [2019-07-26 15:57:15Z]: converter std: 2019-07-26 15:57:15,954 [INFO ]  Found model dir /tmp/xh3x4a4g.d4z/input/resnet50-4
# [2019-07-26 15:57:15Z]: converter std: 2019-07-26 15:57:15,954 [INFO ]  Trying to load input directory with SavedModelLoader
# [2019-07-26 15:57:15Z]: converter err: 2019-07-26 15:57:15.967419: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# [2019-07-26 15:57:20Z]: converter std: 2019-07-26 15:57:20,471 [INFO ]  Restoring parameters from /tmp/xh3x4a4g.d4z/input/resnet50-4/variables/variables
# [2019-07-26 15:57:20Z]: converter err: /usr/lib/python3/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from &#96;float&#96; to &#96;np.floating&#96; is deprecated. In future, it will be treated as &#96;np.float64 == np.dtype(float).type&#96;.
# [2019-07-26 15:57:20Z]: converter err:   from ._conv import register_converters as _register_converters
# [2019-07-26 15:57:20Z]: converter err: INFO:tensorflow:Restoring parameters from /tmp/xh3x4a4g.d4z/input/resnet50-4/variables/variables
# [2019-07-26 15:57:22Z]: converter std: 2019-07-26 15:57:22,535 [INFO ]  Attempt splitting into ONNX FPGA Graph
# [2019-07-26 15:57:22Z]: converter std: 2019-07-26 15:57:22,536 [INFO ]  Splitting into 3 stage pipeline
# [2019-07-26 15:57:22Z]: converter std: 2019-07-26 15:57:22,565 [INFO ]  Found brainwave model of type BrainwaveModel.Resnet50
# [2019-07-26 15:57:23Z]: converter std: 2019-07-26 15:57:23,414 [INFO ]  Adding stage TensorFlow Placeholder:0 --&gt; brainwave_resnet50_1_Version_0.1_input_1
# [2019-07-26 15:57:23Z]: converter std: 2019-07-26 15:57:23,415 [INFO ]  Adding stage Brainwave brainwave_resnet50_1_Version_0.1_input_1 --&gt; brainwave_resnet50_1_Version_0.1_output_1
# [2019-07-26 15:57:23Z]: converter std: 2019-07-26 15:57:23,416 [INFO ]  Adding stage TensorFlow brainwave_resnet50_1_Version_0.1_output_1 --&gt; classifier/resnet_v1_50/predictions/Softmax:0
# [2019-07-26 15:57:23Z]: converter err: INFO:tensorflow:Froze 0 variables.
# [2019-07-26 15:57:23Z]: converter std: 2019-07-26 15:57:23,849 [INFO ]  Froze 0 variables.
# [2019-07-26 15:57:24Z]: converter err: 2019-07-26 15:57:24.240016: W tensorflow/core/graph/graph_constructor.cc:1265] Importing a graph with a lower producer version 24 into an existing graph with producer version 27. Shape inference will have run different parts of the graph with different producer versions.
# [2019-07-26 15:57:25Z]: converter std: Converted 0 variables to const ops.
# [2019-07-26 15:57:25Z]: converter std: 2019-07-26 15:57:25,055 [INFO ]  There are 265 variable names in original BW graph
# [2019-07-26 15:57:25Z]: converter std: 2019-07-26 15:57:25,057 [INFO ]  Found 265 matching variables in existing session
# [2019-07-26 15:57:29Z]: converter err: INFO:tensorflow:Restoring parameters from /tmp/tmppfziwl0d/bw_checkpoints/resnet50
# [2019-07-26 15:57:29Z]: converter std: 2019-07-26 15:57:29,057 [INFO ]  Restoring parameters from /tmp/tmppfziwl0d/bw_checkpoints/resnet50
# [2019-07-26 15:57:30Z]: converter err: INFO:tensorflow:Froze 265 variables.
# [2019-07-26 15:57:30Z]: converter std: 2019-07-26 15:57:30,303 [INFO ]  Froze 265 variables.
# [2019-07-26 15:57:31Z]: converter std: Converted 265 variables to const ops.
# [2019-07-26 15:57:31Z]: converter err: INFO:tensorflow:Froze 0 variables.
# [2019-07-26 15:57:31Z]: converter std: 2019-07-26 15:57:31,272 [INFO ]  Froze 0 variables.
# [2019-07-26 15:57:31Z]: converter std: Converted 0 variables to const ops.
# [2019-07-26 15:57:31Z]: converter std: 2019-07-26 15:57:31,467 [INFO ]  Parse manifest file generated by splitter
# [2019-07-26 15:57:31Z]: converter std: 2019-07-26 15:57:31,470 [INFO ]  Processing tensorflow stage
# [2019-07-26 15:57:31Z]: converter std: 2019-07-26 15:57:31,470 [INFO ]  Processing brainwave stage
# [2019-07-26 15:57:31Z]: converter std: 2019-07-26 15:57:31,471 [INFO ]  Invoking python3 /converter/external/brainwave/tensorflow_params_to_caffe.py -n ResNet-50 -c /data/models/resnet50/model.prototxt -t /tmp/tmppfziwl0d/bw_checkpoints/resnet50 -o /tmp/tmpkoubc1t9/model_caffe.out
# [2019-07-26 15:57:43Z]: converter std: 2019-07-26 15:57:43,969 [INFO ]  Brainwave compiler output:
# [2019-07-26 15:57:43Z]: converter std: [2019-07-26 15:57:33.382157] Execution started.
# [2019-07-26 15:57:43Z]: converter std: 2019-07-26 15:57:33.438184: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# [2019-07-26 15:57:43Z]: converter std: [2019-07-26 15:57:33.444563] Importing tensorflow graph... Done.
# [2019-07-26 15:57:43Z]: converter std: [2019-07-26 15:57:38.111514] Restoring variables... Done.
# [2019-07-26 15:57:43Z]: converter std: [2019-07-26 15:57:39.008544] Converting to Caffe... Done.
# [2019-07-26 15:57:43Z]: converter std: [2019-07-26 15:57:42.776316] Serializing protocol buffer output... Done.
# [2019-07-26 15:57:43Z]: converter std: [2019-07-26 15:57:43.361127] Execution finished. Execution took 9.978955 seconds
# [2019-07-26 15:57:43Z]: converter std: /usr/lib/python3/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from &#96;float&#96; to &#96;np.floating&#96; is deprecated. In future, it will be treated as &#96;np.float64 == np.dtype(float).type&#96;.
# [2019-07-26 15:57:43Z]: converter std:   from ._conv import register_converters as _register_converters
# [2019-07-26 15:57:43Z]: converter std: 2019-07-26 15:57:43,970 [INFO ]  Invoking python3 /converter/external/brainwave/generate_firmware.py --output_format=code -i /data/models/resnet50/model.prototxt -mp /tmp/tmpkoubc1t9/model_caffe.out -if /tmp/tmpkoubc1t9/subgraph.graphir -o /tmp/tmpkoubc1t9/firmware.c -off --v3_isa --double_buffer_parameters --back_propagate_strides --prefetch_matrices --merge_layers --disable_agregation_af

# %%
# ----------------------------------
# PACKAGE MODEL into an IMAGE
# 
# ----------------------------------
from azureml.core.image import Image
from azureml.accel import AccelContainerImage

image_config = AccelContainerImage.image_configuration()
# Image name must be lowercase
image_name = "{}-image".format(model_name)

image = Image.create(name = image_name,
                     models = [converted_model],
                     image_config = image_config, 
                     workspace = ws)
image.wait_for_creation(show_output = False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Creating image
#
# Image creation operation finished for image resnet50-4-image:1, operation &quot;Succeeded&quot;
# </div>

# %%
# ----------------------------------
# PROVISION -> Azure Kubernetes Service (AKS) Cluster using Azure ML Service
# Create AKS ComputeTarget -> StandardPB6s (FPGA-Enabled) - Need Special Access!!!
# This can take awhile!!!
# ----------------------------------
from azureml.core.compute import AksCompute, ComputeTarget

# Uses the specific FPGA enabled VM (sku: Standard_PB6s)
# Standard_PB6s are available in: eastus, westus2, westeurope, southeastasia
# (old) Standard_D3_v2
# If you are not able to deploy, please fill out a request form 
# with your subscription ID and region you want to deploy to: https://aka.ms/accelerateAI

prov_config = AksCompute.provisioning_configuration(vm_size = "Standard_PB6s",
                                                    agent_count = 1, 
                                                    location = "eastus")

aks_name = 'JB-FPGA-aks-pb6'
# Create the cluster
aks_target = ComputeTarget.create(workspace = ws, 
                                  name = aks_name, 
                                  provisioning_configuration = prov_config)
aks_target.wait_for_completion(show_output = True)
print(aks_target.provisioning_state)
print(aks_target.provisioning_errors)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Creating..................................................................................................................................................
# SucceededProvisioning operation finished, operation &quot;Succeeded&quot;
# Succeeded
# None
# </div>

# %%
# -------------------------------------------------------
# DEPLOY -  AccelContainerImage to AKS ComputeTarget
# -------------------------------------------------------
from azureml.core.webservice import Webservice, AksWebservice

#Set the web service configuration (for creating a test service, we don't want autoscale enabled)
# Authentication is enabled by default, but for testing we specify False
aks_config = AksWebservice.deploy_configuration(autoscale_enabled=False,
                                                num_replicas=1,
                                                auth_enabled = False)

aks_service_name ='jb-fpga-aks-service-3'

aks_service = Webservice.deploy_from_image(workspace = ws,
                                           name = aks_service_name,
                                           image = image,
                                           deployment_config = aks_config,
                                           deployment_target = aks_target)
aks_service.wait_for_deployment(show_output = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Creating service
# Running..................................
# SucceededAKS service creation operation finished, operation &quot;Succeeded&quot;
# </div>

# %%
# Get AML WebService IP and Port by Name
from azureml.core.webservice import Webservice
service = Webservice(workspace=ws, name='jb-fpga-aks-service-3')
print(service.scoring_uri)
print(service.name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">http://40.117.41.1/
# jb-fpga-aks-service-3
# </div>

# %%
# Using the grpc client in Azure ML Accelerated Models SDK package
from azureml.accel import PredictionClient

address = aks_service.scoring_uri
ssl_enabled = address.startswith("https")
address = address[address.find('/')+2:].strip('/')
port = 443 if ssl_enabled else 80

# Initialize AzureML Accelerated Models client
client = PredictionClient(address=address,
                          port=port,
                          use_ssl=ssl_enabled,
                          service_name=aks_service.name)
print(address)
print(aks_service.name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">40.117.41.1
# jb-fpga-aks-service-3
# </div>

# %%
import time
import requests
classes_entries = requests.get("https://raw.githubusercontent.com/Lasagne/Recipes/master/examples/resnet50/imagenet_classes.txt").text.splitlines()
start_time = time.time()

from azure.storage.blob import BlockBlobService
block_blob_service = BlockBlobService(account_name='jbadbsa', account_key='0ofZa0xn0kJ98oE/hZINE9/oKFvLWbaTtD+mbAqHnIDMfZ/ml/j+Wwq9iVIJUBks6IUjSvUqZ/gXvk6tCavlXw==')
#block_blob_service.get_blob_to_path('images', 'Snowleopard.jpg', 'TestImage.jpg')
#block_blob_service.get_blob_to_path('images', 'Unicycle.jpg', 'TestImage.jpg')
block_blob_service.get_blob_to_path('images', 'PirateShip.jpg', 'TestImage.jpg')

print(service.scoring_uri)

# Score image with input and output tensor names
results = client.score_file(path="TestImage.jpg", 
                             input_name=input_tensors, 
                             outputs=output_tensors)

print("--- %s seconds ---" % (time.time() - start_time))
print(input_tensors)
print(output_tensors)

# map results [class_id] => [confidence]
results = enumerate(results)
# sort results by confidence
sorted_results = sorted(results, key=lambda x: x[1], reverse=True)
# print top 5 results
for top in sorted_results[:5]:
    print(classes_entries[top[0]], 'confidence:', top[1])
    
print(service)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">http://40.117.41.1/
# --- 0.09512662887573242 seconds ---
# Placeholder:0
# classifier/resnet_v1_50/predictions/Softmax:0
# pirate, pirate ship confidence: 0.9977138
# schooner confidence: 0.0022800476
# yawl confidence: 3.4179563e-06
# dock, dockage, docking facility confidence: 1.7166842e-06
# wreck confidence: 5.6538266e-07
# AksWebservice(workspace=Workspace.create(name=&apos;jbfpgamlws&apos;, subscription_id=&apos;82d7b191-5a8c-4cbf-a9f9-9aa5fb50feaa&apos;, resource_group=&apos;jbfpga&apos;), name=jb-fpga-aks-service-3, image_id=resnet50-4-image:1, compute_type=AKS, state=Healthy, scoring_uri=http://40.117.41.1/, tags={}, properties={})
# </div>

# %%
# ------------------------------
# DELETE Resources (must be done in this order)
# ------------------------------
#aks_service.delete()
#aks_target.delete()
#image.delete()
#registered_model.delete()
#converted_model.delete()
